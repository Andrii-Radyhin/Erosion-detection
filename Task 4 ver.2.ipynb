# %%
import os

import rasterio
from rasterio.plot import reshape_as_image
import rasterio.mask
from rasterio.features import rasterize

import pandas as pd
import geopandas as gpd
from shapely.geometry import mapping, Point, Polygon
from shapely.ops import cascaded_union

import numpy as np
import cv2
import matplotlib.pyplot as plt

import albumentations as A
from albumentations.augmentations.geometric.resize import LongestMaxSize

# %matplotlib inline

# %%
raster_path = 'T36UXV_20200406T083559_TCI_10m.jp2'
with rasterio.open(raster_path, 'r', driver = 'JP2OpenJPEG') as src:
    big_img = src.read()
    img_meta = src.meta

raster_path = 'big_mask.jp2'
with rasterio.open(raster_path, 'r', driver = 'JP2OpenJPEG') as src:
    big_mask = src.read()
    mask_meta = src.meta

# %%
print(big_img.shape, big_mask.shape)
# Out:
# (3, 10980, 10980) (1, 10980, 10980)

# %%
big_img = reshape_as_image(big_img)
big_mask = reshape_as_image(big_mask)

c_img_path = "cropped_img"
c_mask_path = "cropped_mask"

def crop_img(big_img, shape, outfolder):
    i = 0
    for r in range(0,big_img.shape[0],shape[0]):
        for c in range(0,big_img.shape[1],shape[1]):
            img_path = os.path.join(outfolder, f'{i}.png')
            if r+shape[0] <= big_img.shape[0] and c + shape[1] <= big_img.shape[1]:
                cv2.imwrite(img_path, cv2.cvtColor(big_img[r:r+shape[0], c:c+shape[1],:], cv2.COLOR_RGB2BGR))
                i += 1
                
crop_img(big_img, (256, 256), c_img_path)
crop_img(big_mask, (256, 256), c_mask_path)

# %%
BASE_DIR = ''
TRAIN_DIR = BASE_DIR + 'cropped_img/'
MASK_DIR = BASE_DIR + 'cropped_mask/'
INPUT_SIZE = (256,256,3)

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
#from skimage.io import imread
#from skimage.morphology import binary_opening, disk, label
import tensorflow as tf
import keras.backend as K
import albumentations as albu

# %%
train = os.listdir(TRAIN_DIR)
mask = os.listdir(MASK_DIR)

print(f"Train files: {len(train)}. ---> {train[:3]}")
print(f"Test files :  {len(mask)}. ---> {mask[:3]}")
# Out:
# Train files: 1764. ---> ['0.png', '1.png', '10.png']
# Test files :  1764. ---> ['0.png', '1.png', '10.png']

# %%
out_rgb = []
out_mask = []

counter_empty = 0

for p_img, p_mask in zip(train, mask):   
    img_path = os.path.join(TRAIN_DIR, p_img)
    mask_path = os.path.join(MASK_DIR, p_mask)
    
    img = cv2.cvtColor(cv2.imread(img_path), cv2.COLOR_BGR2RGB) / 255.
    mask = cv2.imread(mask_path)
    
    mask = mask[:, :, :1]
    mask[mask > 0.] = 1.
    
    if 1 not in mask: counter_empty+=1
    
    if not(1 not in mask and counter_empty >= 40):
        out_rgb += [img]
        out_mask += [mask]
        

out_rgb = np.array(out_rgb, dtype = 'float32')
out_mask = np.array(out_mask, dtype = 'float32')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    out_rgb, 
    out_mask, 
    test_size=0.05, 
    shuffle=True)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((287, 256, 256, 3), (16, 256, 256, 3), (287, 256, 256, 1), (16, 256, 256, 1))

# %%
aug = A.Compose([
    A.OneOf([
        A.RandomSizedCrop(min_max_height=(50, 101), height=256, width=256, p=0.5),
        A.PadIfNeeded(min_height=256, min_width=256, p=0.5)
    ],p=1),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.OneOf([
        A.ElasticTransform(p=0.5, alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03),
        A.GridDistortion(p=0.5),
        A.OpticalDistortion(distort_limit=1, shift_limit=0.5, p=1),
    ], p=0.8)])

# %%
def make_image_gen(X_train, y_train, aug, batch_size):
    aug_x = []
    aug_y = []
    while True:
        for i in range(X_train.shape[0]): 
            augmented = aug(image=X_train[i], mask=y_train[i])
            x, y = augmented['image'],  augmented['mask']
            aug_x.append(x)
            aug_y.append(y)
            if len(aug_x)>=batch_size:
                yield np.array(aug_x, dtype = 'float32'), np.array(aug_y, dtype = 'float32')
                aug_x, aug_y=[], []

# %%
train_gen = make_image_gen(X_train, y_train, aug, 32)
aug_x, aug_y = next(train_gen)

# %%
np.shape(aug_x), np.shape(aug_y)
# Out:
# ((32, 256, 256, 3), (32, 256, 256, 1))

# %%
IoU = tf.keras.metrics.MeanIoU(num_classes=2)

def dice_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
    return dice

ALPHA = 0.8
GAMMA = 2

def FocalLoss(targets, inputs, alpha=ALPHA, gamma=GAMMA):    
    
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    BCE = K.binary_crossentropy(targets, inputs)
    BCE_EXP = K.exp(-BCE)
    focal_loss = K.mean(alpha * K.pow((1-BCE_EXP), gamma) * BCE)
    
    return focal_loss

# %%
callbacks = [
    #tf.keras.callbacks.EarlyStopping(monitor="val_loss", mode="min", patience=5),
    tf.keras.callbacks.ModelCheckpoint(filepath='crusa.h5', monitor = 'val_loss', verbose = 1, save_best_only = True, mode = 'min'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, 
                                   verbose=1, mode='min', min_delta=0.0001, cooldown=2, min_lr=1e-6)   
]

# %%
import segmentation_models as sm
sm.set_framework('tf.keras')

sm.framework()

model = sm.Unet('efficientnetb0', classes=1, input_shape=(256, 256, 3), activation='sigmoid', encoder_weights='imagenet')
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=FocalLoss, metrics = [IoU, dice_coef] )
# Out:
# Segmentation Models: using `keras` framework.

# %%
model.fit_generator(generator=make_image_gen(X_train, y_train, aug, 16),epochs=50, steps_per_epoch = 200, callbacks = callbacks,validation_data = (X_test, y_test))
# Out:
# Epoch 1/50
# 200/200 [==============================] - 47s 220ms/step - loss: 0.0221 - mean_io_u: 0.4926 - dice_coef: 0.0247 - val_loss: 0.0204 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0264
#
# Epoch 00001: val_loss improved from inf to 0.02044, saving model to crusa.h5
# C:\Users\Andrey\anaconda3\envs\ev_2\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/50
# 200/200 [==============================] - 43s 213ms/step - loss: 0.0150 - mean_io_u: 0.4931 - dice_coef: 0.0288 - val_loss: 0.0202 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0249
#
# Epoch 00002: val_loss improved from 0.02044 to 0.02015, saving model to crusa.h5
# Epoch 3/50
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0148 - mean_io_u: 0.4928 - dice_coef: 0.0317 - val_loss: 0.0140 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0384
#
# Epoch 00003: val_loss improved from 0.02015 to 0.01399, saving model to crusa.h5
# Epoch 4/50
# 200/200 [==============================] - 43s 213ms/step - loss: 0.0139 - mean_io_u: 0.4933 - dice_coef: 0.0314 - val_loss: 0.0125 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0515
#
# Epoch 00004: val_loss improved from 0.01399 to 0.01246, saving model to crusa.h5
# Epoch 5/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0134 - mean_io_u: 0.4933 - dice_coef: 0.0331 - val_loss: 0.0124 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0476
#
# Epoch 00005: val_loss improved from 0.01246 to 0.01239, saving model to crusa.h5
# Epoch 6/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0135 - mean_io_u: 0.4929 - dice_coef: 0.0366 - val_loss: 0.0123 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0550
#
# Epoch 00006: val_loss improved from 0.01239 to 0.01234, saving model to crusa.h5
# Epoch 7/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0134 - mean_io_u: 0.4927 - dice_coef: 0.0375 - val_loss: 0.0118 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0532
#
# Epoch 00007: val_loss improved from 0.01234 to 0.01176, saving model to crusa.h5
# Epoch 8/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0127 - mean_io_u: 0.4930 - dice_coef: 0.0380 - val_loss: 0.0118 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0497
#
# Epoch 00008: val_loss did not improve from 0.01176
# Epoch 9/50
# 200/200 [==============================] - 43s 213ms/step - loss: 0.0124 - mean_io_u: 0.4929 - dice_coef: 0.0400 - val_loss: 0.0124 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0560
#
# Epoch 00009: val_loss did not improve from 0.01176
# Epoch 10/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0124 - mean_io_u: 0.4929 - dice_coef: 0.0397 - val_loss: 0.0126 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0585
#
# Epoch 00010: val_loss did not improve from 0.01176
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 11/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0114 - mean_io_u: 0.4933 - dice_coef: 0.0404 - val_loss: 0.0121 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0576
#
# Epoch 00011: val_loss did not improve from 0.01176
# Epoch 12/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0116 - mean_io_u: 0.4931 - dice_coef: 0.0422 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0600
#
# Epoch 00012: val_loss improved from 0.01176 to 0.01166, saving model to crusa.h5
# Epoch 13/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0110 - mean_io_u: 0.4932 - dice_coef: 0.0445 - val_loss: 0.0135 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0549
#
# Epoch 00013: val_loss did not improve from 0.01166
# Epoch 14/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0107 - mean_io_u: 0.4935 - dice_coef: 0.0427 - val_loss: 0.0121 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0620
#
# Epoch 00014: val_loss did not improve from 0.01166
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 15/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0107 - mean_io_u: 0.4928 - dice_coef: 0.0488 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0666
#
# Epoch 00015: val_loss did not improve from 0.01166
# Epoch 16/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0100 - mean_io_u: 0.4933 - dice_coef: 0.0476 - val_loss: 0.0109 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0706
#
# Epoch 00016: val_loss improved from 0.01166 to 0.01089, saving model to crusa.h5
# Epoch 17/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0102 - mean_io_u: 0.4932 - dice_coef: 0.0487 - val_loss: 0.0126 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0668
#
# Epoch 00017: val_loss did not improve from 0.01089
# Epoch 18/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0098 - mean_io_u: 0.4931 - dice_coef: 0.0501 - val_loss: 0.0121 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0675
#
# Epoch 00018: val_loss did not improve from 0.01089
# Epoch 19/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0102 - mean_io_u: 0.4930 - dice_coef: 0.0503 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0730
#
# Epoch 00019: val_loss did not improve from 0.01089
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 20/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0096 - mean_io_u: 0.4930 - dice_coef: 0.0536 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0739
#
# Epoch 00020: val_loss did not improve from 0.01089
# Epoch 21/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0095 - mean_io_u: 0.4929 - dice_coef: 0.0560 - val_loss: 0.0121 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0713
#
# Epoch 00021: val_loss did not improve from 0.01089
# Epoch 22/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0094 - mean_io_u: 0.4932 - dice_coef: 0.0524 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0746
#
# Epoch 00022: val_loss did not improve from 0.01089
# Epoch 23/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0091 - mean_io_u: 0.4935 - dice_coef: 0.0539 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0730
#
# Epoch 00023: val_loss did not improve from 0.01089
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 24/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0093 - mean_io_u: 0.4930 - dice_coef: 0.0558 - val_loss: 0.0118 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0747
#
# Epoch 00024: val_loss did not improve from 0.01089
# Epoch 25/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0091 - mean_io_u: 0.4932 - dice_coef: 0.0563 - val_loss: 0.0116 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0764
#
# Epoch 00025: val_loss did not improve from 0.01089
# Epoch 26/50
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0090 - mean_io_u: 0.4932 - dice_coef: 0.0556 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0749
#
# Epoch 00026: val_loss did not improve from 0.01089
# Epoch 27/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0092 - mean_io_u: 0.4930 - dice_coef: 0.0568 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0769
#
# Epoch 00027: val_loss did not improve from 0.01089
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 28/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0092 - mean_io_u: 0.4927 - dice_coef: 0.0598 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0766
#
# Epoch 00028: val_loss did not improve from 0.01089
# Epoch 29/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0089 - mean_io_u: 0.4931 - dice_coef: 0.0577 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0758
#
# Epoch 00029: val_loss did not improve from 0.01089
# Epoch 30/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0094 - mean_io_u: 0.4928 - dice_coef: 0.0570 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0761
#
# Epoch 00030: val_loss did not improve from 0.01089
# Epoch 31/50
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0087 - mean_io_u: 0.4933 - dice_coef: 0.0565 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0772
#
# Epoch 00031: val_loss did not improve from 0.01089
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 32/50
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0092 - mean_io_u: 0.4931 - dice_coef: 0.0557 - val_loss: 0.0117 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0779
#
# Epoch 00032: val_loss did not improve from 0.01089
# Epoch 33/50
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0087 - mean_io_u: 0.4932 - dice_coef: 0.0571 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0785
#
# Epoch 00033: val_loss did not improve from 0.01089
# Epoch 34/50
# 200/200 [==============================] - 42s 210ms/step - loss: 0.0085 - mean_io_u: 0.4933 - dice_coef: 0.0581 - val_loss: 0.0118 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0797
#
# Epoch 00034: val_loss did not improve from 0.01089
# Epoch 35/50
# 200/200 [==============================] - 42s 209ms/step - loss: 0.0088 - mean_io_u: 0.4928 - dice_coef: 0.0611 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0792
#
# Epoch 00035: val_loss did not improve from 0.01089
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 36/50
# 200/200 [==============================] - 42s 209ms/step - loss: 0.0088 - mean_io_u: 0.4931 - dice_coef: 0.0581 - val_loss: 0.0120 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0800
#
# Epoch 00036: val_loss did not improve from 0.01089
# Epoch 37/50
# 200/200 [==============================] - 42s 209ms/step - loss: 0.0091 - mean_io_u: 0.4930 - dice_coef: 0.0573 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0797
#
# Epoch 00037: val_loss did not improve from 0.01089
# Epoch 38/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0090 - mean_io_u: 0.4931 - dice_coef: 0.0578 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0791
#
# Epoch 00038: val_loss did not improve from 0.01089
# Epoch 39/50
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0086 - mean_io_u: 0.4934 - dice_coef: 0.0571 - val_loss: 0.0118 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0790
#
# Epoch 00039: val_loss did not improve from 0.01089
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 40/50
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0079 - mean_io_u: 0.4937 - dice_coef: 0.0563 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0796
#
# Epoch 00040: val_loss did not improve from 0.01089
# Epoch 41/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0086 - mean_io_u: 0.4932 - dice_coef: 0.0583 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0798
#
# Epoch 00041: val_loss did not improve from 0.01089
# Epoch 42/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0082 - mean_io_u: 0.4936 - dice_coef: 0.0580 - val_loss: 0.0120 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0792
#
# Epoch 00042: val_loss did not improve from 0.01089
# Epoch 43/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0088 - mean_io_u: 0.4930 - dice_coef: 0.0589 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0796
#
# Epoch 00043: val_loss did not improve from 0.01089
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 44/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0089 - mean_io_u: 0.4929 - dice_coef: 0.0601 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0793
#
# Epoch 00044: val_loss did not improve from 0.01089
# Epoch 45/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0087 - mean_io_u: 0.4933 - dice_coef: 0.0573 - val_loss: 0.0120 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0796
#
# Epoch 00045: val_loss did not improve from 0.01089
# Epoch 46/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0087 - mean_io_u: 0.4930 - dice_coef: 0.0595 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0795
#
# Epoch 00046: val_loss did not improve from 0.01089
# Epoch 47/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0085 - mean_io_u: 0.4932 - dice_coef: 0.0573 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0797
#
# Epoch 00047: val_loss did not improve from 0.01089
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 48/50
# 200/200 [==============================] - 43s 214ms/step - loss: 0.0093 - mean_io_u: 0.4928 - dice_coef: 0.0594 - val_loss: 0.0119 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0797
#
# Epoch 00048: val_loss did not improve from 0.01089
# Epoch 49/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0082 - mean_io_u: 0.4934 - dice_coef: 0.0580 - val_loss: 0.0120 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0800
#
# Epoch 00049: val_loss did not improve from 0.01089
# Epoch 50/50
# 200/200 [==============================] - 42s 212ms/step - loss: 0.0088 - mean_io_u: 0.4930 - dice_coef: 0.0582 - val_loss: 0.0120 - val_mean_io_u: 0.4934 - val_dice_coef: 0.0799
#
# Epoch 00050: val_loss did not improve from 0.01089

# %%
rows = 1
columns = 3
preds = model.predict(X_test)

for img, pred, g_truth in zip(X_test[5:10], preds[5:10], y_test[5:10]):
    fig = plt.figure(figsize=(10, 7))
    fig.add_subplot(rows, columns, 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title("Image")
    fig.add_subplot(rows, columns, 2)
    #pred = cv2.cvtColor(pred, cv2.COLOR_BGR2RGB)
    plt.imshow(pred, interpolation=None)
    plt.axis('off')
    plt.title("Prediction")
    fig.add_subplot(rows, columns, 3)
    plt.imshow(g_truth, interpolation=None)
    plt.axis('off')
    plt.title("Ground truth")

# %%
model.save('model.h5')
